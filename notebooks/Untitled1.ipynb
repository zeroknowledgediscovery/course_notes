# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
# Out:
# /home/ishanu/.local/lib/python3.7/site-packages/statsmodels/compat/pandas.py:49: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   data_klasses = (pandas.Series, pandas.DataFrame, pandas.Panel)

# %%
data=pd.read_csv('../datasets/covid_epidemiology.csv') # assume columns ar Y XA XB
data.fips=[str(x).zfill(5) for x in data.fips]
data['Y']=data['11/27/20']

# %%
data.head()
# Out:
#     fips  65yrs  minority  black  hispanic  population  perc_65yrs  \
# 0  01001   8924     13262  11237      1671       55869    0.159731
# 1  01003  46830     28036  19593     10534      223234    0.209780
# 2  01005   4861     12552  11906      1117       24686    0.196913
# 3  01007   3733      5203   4763       623       22394    0.166696
# 4  01009  10814      2414    978      5582       57826    0.187009
#
#    perc_minority  perc_black  perc_hispanic  ...  11/27/20  11/28/20  \
# 0       0.237377    0.201131       0.029909  ...      2716      2735
# 1       0.125590    0.087769       0.047188  ...      8603      8733
# 2       0.508466    0.482298       0.045248  ...      1171      1173
# 3       0.232339    0.212691       0.027820  ...      1173      1179
# 4       0.041746    0.016913       0.096531  ...      2888      2922
#
#    11/29/20  11/30/20  12/1/20  12/2/20 12/3/20  12/4/20  12/5/20  12/6/20
# ...

# %%
formula = 'Y ~  perc_minority + 65yrs + 65yrs*black'

# %%
mod1 = smf.glm(formula=formula, data=data).fit()
# Out:
# Traceback (most recent call last):
#
#   File "/usr/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-12-96744c54ddb3>", line 1, in <module>
#     mod1 = smf.glm(formula=formula, data=data).fit()
#
#   File "/home/ishanu/.local/lib/python3.7/site-packages/statsmodels/base/model.py", line 155, in from_formula
#     missing=missing)
#
#   File "/home/ishanu/.local/lib/python3.7/site-packages/statsmodels/formula/formulatools.py", line 65, in handle_formula_data
#     NA_action=na_action)
#
#   File "/home/ishanu/.local/lib/python3.7/site-packages/patsy/highlevel.py", line 310, in dmatrices
#     NA_action, return_type)
#
#   File "/home/ishanu/.local/lib/python3.7/site-packages/patsy/highlevel.py", line 165, in _do_highlevel_design
#     NA_action)
#
#   File "/home/ishanu/.local/lib/python3.7/site-packages/patsy/highlevel.py", line 70, in _try_incr_builders
# ...
